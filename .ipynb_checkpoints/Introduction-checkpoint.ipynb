# %%
import pandas as pd
import zipfile

filename = "ETHUSDT--kline--2021-04-23--2022-04-23.zip"

zf = zipfile.ZipFile(filename) 
df = pd.read_csv(zf.open(filename))
df.head()
# Out:
#        open_time     open     high      low    close      volume  \
# 0  1617235200000  1919.37  1931.39  1919.37  1930.38  1523.75704
# 1  1617235260000  1930.39  1933.00  1928.83  1932.49   638.85329
# 2  1617235320000  1932.49  1937.00  1931.41  1936.09  1442.39900
# 3  1617235380000  1936.09  1937.82  1935.17  1936.96   860.88224
# 4  1617235440000  1936.83  1936.99  1931.59  1934.49   589.06457
#
#       close_time  quote_asset_volume  number_of_trades  \
# 0  1617235259999        2.934700e+06              2511
# 1  1617235319999        1.233546e+06              1136
# 2  1617235379999        2.791260e+06              1528
# 3  1617235439999        1.667153e+06              1075
# 4  1617235499999        1.139361e+06               898
#
#    taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ignore
# 0                    886.72411                  1.707531e+06       0
# 1                    317.63296                  6.133780e+05       0
# ...
